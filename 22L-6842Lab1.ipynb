# %%
s= input("Enter your name: ")
a= input("Enter your age: ")
print("Hello", s , a)
# Out:
# Enter your name: Aleesha
# Enter your age: 21
# Hello Aleesha 21

# %%
number = input()

if '.' in number:
    print("Is Float")
    number = float(number)
else:
    print("Is integer")
    number = int(float(number))
# Out:
# 12.4
# Is Float

# %%
number = int(input())
if number>0:
  print("Positive")
elif number<0:
  print("Negative")
elif number==0:
  print("Zero")
if number%2==0:
  print("Even")
else:
  print("Odd")
# Out:
# 12
# Positive
# Even

# %%
import numpy as np
i = 1
while i <=50:
    if (i % 3 == 0 and i % 5 == 0):
        print("FizzBuzz")
    elif (i% 3 == 0):
        print("Fizz")
    elif (i% 5 == 0):
        print("Buzz")
    else:
        print(i)
    i += 1
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# 28
# 29
# FizzBuzz
# 31
# 32
# Fizz
# 34
# Buzz
# Fizz
# 37
# 38
# Fizz
# Buzz
# 41
# Fizz
# 43
# 44
# FizzBuzz
# 46
# 47
# Fizz
# 49
# Buzz

# %%
a = int(input())
i = 2
count = 0

while i < a/2:
         if (a % i == 0):
             count = count + 1
         i = i + 1
if (count == 0 and a!=1):
         print("Prime")
else:
         print("Not Prime")
# Out:
# 13
# Prime

# %%
def is_palindrome(string):
  string = string.lower().replace(" ", "")
  return string == string[::-1]

string = input("Enter a string: ")

if is_palindrome(string):
  print(f"'{string}' is a palindrome.")
else:
  print(f"'{string}' is not a palindrome.")
# Out:
# Enter a string: abBa
# 'abBa' is a palindrome.

# %%
x=lambda s: s==s[::-1]
s=input("Enter a string: ")
if x(s):
  print("Palindrome")
else:
  print("Not Palindrome")
# Out:
# Enter a string: civic
# Palindrome

# %%
a= int(input())
ans=a
while a>1:
  ans=ans*(a-1);
  a=a-1;
print("Fictorial= ",ans)
# Out:
# 5
# 120

# %%
sg= {}
for i in range(5):
    name = input(f"Enter the name of student {i + 1}: ")
    grade = input(f"Enter the grade for {name}: ")
    sg[name] = grade
print("Student Grades:")
print(sg)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-84-378bf9909960> in <cell line: 0>()
#       1 sg= {}
#       2 for i in range(5):
# ----> 3     name = input(f"Enter the name of student {i + 1}: ")
#       4     grade = input(f"Enter the grade for {name}: ")
#       5     sg[name] = grade
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
# ...

# %%
sg={}
count=1;
for i in range(5):
   name = input(f"Enter a word: ")
   sg[i]=name
for j in range(len(sg)):
   k=j+1
   count=0
   for k in range (len(sg)):
    if sg[j]==sg[k]:
      count=count+1
   print("Count of " , sg[j] , "=" , count)
# Out:
# Enter a word: hello
# Enter a word: my
# Enter a word: world
# Enter a word: my
# Enter a word: hello
# Count of  hello = 2
# Count of  my = 2
# Count of  world = 1
# Count of  my = 2
# Count of  hello = 2

# %%
a=float(input("Enter Temperature: "))
b=input("Enter your current unit of temp i.e F or C: ")
if b=='F':
  C=((a)-32)*(5/9)
  print("Temperature in Celsius: ", C,"C")
elif b=='C':
  F=(a*9/5)+32
  print("Temperature in Fahrenheit: ", F,"F")
# Out:
# Enter Temperature: 5
# Enter your current unit of temp i.e F or C: C
# Temperature in Fahrenheit:  41.0 F

# %%
a=int(input("Enter a number: "))
i=1
ans=0
while i<=10:
  ans=i*a
  print(i, "*", a, "=" , ans  )
  i=i+1
# Out:
# Enter a number: 4
# 1 * 4 = 4
# 2 * 4 = 8
# 3 * 4 = 12
# 4 * 4 = 16
# 5 * 4 = 20
# 6 * 4 = 24
# 7 * 4 = 28
# 8 * 4 = 32
# 9 * 4 = 36
# 10 * 4 = 40

# %%
a= int(input("Enter total numbers: "))
i=0
sum=0
while i<a:
  b=int(input("Enter a number: "))
  sum=sum+b
  i=i+1
print("Average= " , sum/a)
# Out:
# Enter total numbers: 3
# Enter a number: 2
# Enter a number: 2
# Enter a number: 2
# Average=  2.0

# %%
list=[]
list.append("abc")
list.append("bcx")
list.append("ahd")
list.append("hi")
list.append("yoo")

print(list)
list.remove("abc")
print(list)
for i in range(len(list)):
  list[i]=list[i].upper()
print(list)
# Out:
# ['abc', 'bcx', 'ahd', 'hi', 'yoo']
# ['bcx', 'ahd', 'hi', 'yoo']
# ['BCX', 'AHD', 'HI', 'YOO']

# %%
t=(1,2,3)
a=t[0]
b=t[1]
print(a)
print(b)
# Out:
# 1
# 2

# %%
list1=[]
list2=[]
for i in range(5):
   list1.append(int(input("Enter number for list 1: ")))
for i in range(5):
   list2.app2end(int(input("Enter a number for list 2: ")))
set1=set(list1)
set2=set(list2)
print("Union: ", set1.union(set2))
print("Intersection: ", set1.intersection(set2))
print("Difference: ", set1.difference(set2))
# Out:
# Enter number for list 1: 1
# Enter number for list 1: 2
# Enter number for list 1: 3
# Enter number for list 1: 4
# Enter number for list 1: 5
# Enter a number for list 2: 4
# Enter a number for list 2: 2
# Enter a number for list 2: 3
# Enter a number for list 2: 1
# Enter a number for list 2: 8
# Union:  {1, 2, 3, 4, 5, 8}
# Intersection:  {1, 2, 3, 4}
# Difference:  {5}

# %%
list1=[]
list2=[]
for i in range(5):
   list1.append(int(input("Enter number for list 1: ")))
for i in range(5):
  list2.append(list1[i]*list1[i])
print(list2)
# Out:
# Enter number for list 1: 2
# Enter number for list 1: 3
# Enter number for list 1: 4
# Enter number for list 1: 5
# Enter number for list 1: 6
# [4, 9, 16, 25, 36]

# %%
a=int(input("Enter a number to calculate its fabonacci sequence: "))
list=[]

if a == 0:
    list = [0]
elif a == 1:
    list = [0, 1]
else:
    list = [0, 1]
    i = 2
    while i < a:
        next_fib = list[i-1] + list[i-2]
        list.append(next_fib)
        i += 1
print(list)
# Out:
# Enter a number to calculate its fabonacci sequence: 6
# [0, 1, 1, 2, 3, 5]

# %%
sg= {}
while True:
  b=input("Enter R to register and L to login or E to exit: ")
  if b=='R':
   name = input(f"Enter your username: ")
   passw= input(f"Enter your password: ")
   sg[name] = passw
   print("Registeration successful")
  elif b=='L':
   name = input(f"Enter your username: ")
   passw= input(f"Enter your password: ")
   if name in sg and passw==sg[name]:
     print("Login successful")
  elif b=='E':
   break

  else:
     print("Login failed")
# Out:
# Enter R to register and L to login or E to exit: E

# %%
d1={
    "a",
    "b",
    "c"
}
print(d1)
d2={
    "a",
    "b",
    "c",
    "f"
}
d1.update(d2)
print(d1)
# Out:
# {'c', 'a', 'b'}
# {'c', 'a', 'b', 'f'}

# %%
def remove_duplicates(lst):
    seen = set()
    result = []
    for item in lst:
        if item not in seen:
            result.append(item)
            seen.add(item)
    return result

list1 = [1, 2, 3, 4, 1, 4, 1, 3, 2, 5, 4]
list1 = remove_duplicates(list1)
print(list1)
# Out:
# [1, 2, 3, 4, 5]
